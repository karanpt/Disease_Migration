# %%
import pandas as pd
import matplotlib.pyplot as plt
var = pd.read_csv(r'pseudo.csv')
df = pd.DataFrame(var,columns=['STATE','DISTRICT','DATE','TOTAL CA4S','CURED(%)','TEMPERATURE','HUMIDITY','PRESSURE','Dew Point','Wind Direction','RAINFALL','DEATHS'])
print (df)
# Out:
#            STATE                  DISTRICT  DATE  TOTAL CA4S  CURED(%)  \
# 0    Maharashtra                     Akola   NaN         125        86
# 1    Maharashtra                  Amravati   NaN         415        87
# 2    Maharashtra                   Buldana   NaN          54        87
# 3    Maharashtra                  Yavatmal   NaN         193        87
# 4    Maharashtra                    Washim   NaN         563        85
# 5    Maharashtra                Aurangabad   NaN         271        85
# 6    Maharashtra                      Beed   NaN         306        85
# 7    Maharashtra                     Jalna   NaN         150        76
# 8    Maharashtra                 Osmanabad   NaN         196        76
# 9    Maharashtra                     Latur   NaN         363        76
# 10   Maharashtra                    Nanded   NaN         399        79
# 11   Maharashtra                  Parbhani   NaN         163        79
# 12   Maharashtra                   Hingoli   NaN         294        79
# 13   Maharashtra                    Mumbai   NaN         267        85
# 14   Maharashtra  Mumbai Suburban District   NaN         110        85
# 15   Maharashtra                     Thane   NaN         168        85
# 16   Maharashtra                   Palghar   NaN         281        87
# 17   Maharashtra                    Raigad   NaN         165        87
# 18   Maharashtra                 Ratnagiri   NaN         345        87
# 19   Maharashtra                Sindhudurg   NaN         119        88
# 20   Maharashtra                  Bhandara   NaN         211        88
# 21   Maharashtra                Chandrapur   NaN         240        88
# 22   Maharashtra                Gadchiroli   NaN         186        90
# 23   Maharashtra                    Gondia   NaN         223        90
# 24   Maharashtra                    Nagpur   NaN          75        90
# 25   Maharashtra                    Wardha   NaN         148        76
# 26   Maharashtra                Ahmednagar   NaN         170        76
# 27   Maharashtra                     Dhule   NaN         143        76
# 28   Maharashtra                   Jalgaon   NaN         197        75
# 29   Maharashtra                 Nandurbar   NaN          89        75
# ..           ...                       ...   ...         ...       ...
# 420  Maharashtra                    Nagpur   NaN         161        90
# 421  Maharashtra                    Wardha   NaN         101        90
# 422  Maharashtra                Ahmednagar   NaN          97        90
# 423  Maharashtra                     Dhule   NaN         399        86
# 424  Maharashtra                   Jalgaon   NaN         178        86
# 425  Maharashtra                 Nandurbar   NaN         148        86
# 426  Maharashtra                    Nashik   NaN         235        84
# 427  Maharashtra                  Kolhapur   NaN         260        84
# 428  Maharashtra                      Pune   NaN         217        84
# 429  Maharashtra                    Sangli   NaN         112        87
# 430  Maharashtra                    Satara   NaN          66        87
# 431  Maharashtra                   Solapur   NaN         110        87
# 432  Maharashtra                     Akola   NaN          12        89
# 433  Maharashtra                  Amravati   NaN          77        89
# 434  Maharashtra                   Buldana   NaN          75        89
# 435  Maharashtra                  Yavatmal   NaN         410        88
# 436  Maharashtra                    Washim   NaN         204        88
# 437  Maharashtra                Aurangabad   NaN         102        88
# 438  Maharashtra                      Beed   NaN          41        75
# 439  Maharashtra                     Jalna   NaN         177        75
# 440  Maharashtra                 Osmanabad   NaN          81        75
# 441  Maharashtra                     Latur   NaN         161        90
# 442  Maharashtra                    Nanded   NaN           7        90
# 443  Maharashtra                  Parbhani   NaN          60        90
# 444  Maharashtra                   Hingoli   NaN          85        82
# 445  Maharashtra                    Mumbai   NaN          41        82
# 446  Maharashtra  Mumbai Suburban District   NaN          79        82
# 447  Maharashtra                     Thane   NaN         208        86
# 448  Maharashtra                   Palghar   NaN         153        86
# 449  Maharashtra                    Raigad   NaN         227        86
#
#      TEMPERATURE  HUMIDITY  PRESSURE  Dew Point  Wind Direction  RAINFALL  \
# 0             28        32     -9999         10               1       NaN
# 1             23        33      1011          6               1       NaN
# 2             20        37      1013          5               1       NaN
# 3             18        40      1015          4               1       NaN
# 4             17        22      1016         -5               7       NaN
# 5             18        49      1017          7               1       NaN
# 6             18        68      1019         12               7       NaN
# 7             15        59      1019          7               1       NaN
# 8             12        72      1019          7               1       NaN
# 9             19        52      1010          9               7       NaN
# 10            19        32      1012          2               1       NaN
# 11            19        78      1014         15               3       NaN
# 12            28        45      1010         15               3       NaN
# 13            25        50      1013         14               6       NaN
# 14            26        32      1011          8               7       NaN
# 15            26        51      1006         15               2       NaN
# 16            30        37      1009         14               7       NaN
# 17            37        15      1003          6               7       NaN
# 18            24        83      1004         21               8       NaN
# 19            27        32      1006          9               1       NaN
# 20            37        32      1001         18               4       NaN
# 21            29        58      1005         20               6       NaN
# 22            35        41     -9999         20               7       NaN
# 23            37        53       992         26               2       NaN
# 24            37        47       995         24               7       NaN
# 25            27       100       992         27               1       NaN
# 26            31        89       999         29               2       NaN
# 27            27       100       994         27               8       NaN
# 28            33        66      1002         26               7       NaN
# 29            26       100       997         26               4       NaN
# ..           ...       ...       ...        ...             ...       ...
# 420           12        58      1015          4               1       NaN
# 421           10        66      1015          4               1       NaN
# 422           23        16      1014         -4               8       NaN
# 423           16        36      1015          1               1       NaN
# 424           15        39      1015          1               1       NaN
# 425           12        51      1016          2               1       NaN
# 426           12        51      1016          2               1       NaN
# 427           13         1     -9999          3               1       NaN
# 428           10        62      1015          3               1       NaN
# 429           10        62      1015          3               1       NaN
# 430           10        62      1015          3               1       NaN
# 431            9        71      1015          4               1       NaN
# 432            9        66      1016          3               1       NaN
# 433            9        62      1016          2               1       NaN
# 434           10        66      1017          4               1       NaN
# 435           12        54      1018          3               6       NaN
# 436           15        45      1018          3               6       NaN
# 437           19        37      1018          4               6       NaN
# 438           21        28      1017          2               6       NaN
# 439           21        27      1017          1               8       NaN
# 440           22        22      1016         -1               7       NaN
# 441           22        22      1015         -1               7       NaN
# 442           22        22      1015         -1               7       NaN
# 443           16        42      1015          3               1       NaN
# 444           14        48      1016          3               1       NaN
# 445           14        51      1016          4               1       NaN
# 446           13        54      1016          4               1       NaN
# 447           12        54      1016          3               1       NaN
# 448           11        58      1016          3               1       NaN
# 449           11        58      1015          3               1       NaN
#
#      DEATHS
# 0        18
# 1        54
# 2         8
# 3        26
# 4        85
# 5        41
# 6        46
# 7        36
# 8        48
# 9        88
# 10       84
# 11       35
# 12       62
# 13       41
# 14       17
# 15       26
# 16       37
# 17       22
# 18       45
# 19       15
# 20       26
# 21       29
# 22       19
# 23       23
# 24        8
# 25       36
# 26       41
# 27       35
# 28       50
# 29       23
# ..      ...
# 420      17
# 421      11
# 422      10
# 423      56
# 424      25
# 425      21
# 426      38
# 427      42
# 428      35
# 429      15
# 430       9
# 431      15
# 432       2
# 433       9
# 434       9
# 435      50
# 436      25
# 437      13
# 438      11
# 439      45
# 440      21
# 441      17
# 442       1
# 443       6
# 444      16
# 445       8
# 446      15
# 447      30
# 448      22
# 449      32
#
# [450 rows x 12 columns]

# %%
plt.scatter(df['TEMPERATURE'], df['DEATHS'], color='red')
plt.title('DEATHS Vs TEMPERATURE', fontsize=14)
plt.xlabel('TEMPERATURE', fontsize=14)
plt.ylabel('DEATHS', fontsize=14)
plt.grid(True)
plt.show()
 
plt.scatter(df['HUMIDITY'], df['DEATHS'], color='green')
plt.title('DEATHS Vs HUMIDITY', fontsize=14)
plt.xlabel('HUMIDITY', fontsize=14)
plt.ylabel('DEATHS', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(df['PRESSURE'], df['DEATHS'], color='red')
plt.title('DEATHS Vs PRESSURE', fontsize=14)
plt.xlabel('PRESSURE', fontsize=14)
plt.ylabel('DEATHS', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(df['Dew Point'], df['DEATHS'], color='green')
plt.title('DEATHS Vs Dew Point', fontsize=14)
plt.xlabel('Dew Point', fontsize=14)
plt.ylabel('DEATHS', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(df['Wind Direction'], df['DEATHS'], color='red')
plt.title('DEATHS Vs Wind Direction', fontsize=14)
plt.xlabel('Wind Direction', fontsize=14)
plt.ylabel('DEATHS', fontsize=14)
plt.grid(True)
plt.show()

plt.scatter(df['RAINFALL'], df['DEATHS'], color='green')
plt.title('DEATHS Vs RAINFALL', fontsize=14)
plt.xlabel('RAINFALL', fontsize=14)
plt.ylabel('DEATHS', fontsize=14)
plt.grid(True)
plt.show()

# %%
from sklearn import linear_model
import statsmodels.api as sm
X = df[['TEMPERATURE','HUMIDITY','PRESSURE','Dew Point','Wind Direction','RAINFALL']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['DEATHS']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)


# prediction with sklearn
New_TEMPERATURE = 33
New_HUMIDITY = 66
New_PRESSURE = 1050
New_Dew_Point = 15
New_Wind_Direction = 2
New_RAINFALL = 1
print ('Predicted Number of deaths: \n', regr.predict([[New_TEMPERATURE ,New_HUMIDITY ,New_PRESSURE ,New_Dew_Point ,New_Wind_Direction ,New_RAINFALL]]))


# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  27.04747584532975
# Coefficients:
#  [-2.69015884e-02  1.07370421e-01 -2.63663106e-04 -2.97491425e-02
#   4.09718832e-01 -2.38427993e+00]
# Predicted Number of deaths:
#  [30.95824558]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 DEATHS   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4821
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):              0.822
# Time:                        11:33:11   Log-Likelihood:                -2096.7
# No. Observations:                 450   AIC:                             4207.
# Df Residuals:                     443   BIC:                             4236.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             27.0475     17.379      1.556      0.120      -7.107      61.202
# TEMPERATURE       -0.0269      0.586     -0.046      0.963      -1.179       1.126
# HUMIDITY           0.1074      0.205      0.524      0.600      -0.295       0.510
# PRESSURE          -0.0003      0.000     -0.552      0.581      -0.001       0.001
# Dew Point         -0.0297      0.664     -0.045      0.964      -1.335       1.276
# Wind Direction     0.4097      0.499      0.822      0.412      -0.570       1.390
# RAINFALL          -2.3843      4.445     -0.536      0.592     -11.121       6.352
# ==============================================================================
# Omnibus:                      122.700   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.187
# Skew:                           1.425   Prob(JB):                     3.52e-59
# Kurtosis:                       5.497   Cond. No.                     3.74e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\karan\Anaconda3\envs\dhana\lib\site-packages\numpy\core\fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
